# %% [markdown]
# # Practical 3

# %%
import pandas as pd
import numpy as np

df=pd.read_csv("https://raw.githubusercontent.com/rushirao17/SPPU-Practs/main/loan_data.csv")
df
# Out:
#       Loan_ID  Gender   Age Married Dependents     Education Self_Employed  \
# 0    LP001002    Male  35.0      No          0      Graduate            No
# 1    LP001003    Male   NaN     Yes          1      Graduate            No
# 2    LP001005    Male  25.0     Yes          0      Graduate           Yes
# 3    LP001006    Male  26.0     Yes          0  Not Graduate            No
# 4    LP001008    Male  30.0      No          0      Graduate            No
# ..        ...     ...   ...     ...        ...           ...           ...
# 609  LP002978  Female  25.0      No          0      Graduate            No
# 610  LP002979    Male  50.0     Yes         3+      Graduate            No
# 611  LP002983    Male  38.0     Yes          1      Graduate            No
# 612  LP002984    Male  45.0     Yes          2      Graduate            No
# 613  LP002990  Female  26.0      No          0      Graduate           Yes
#
# ...

# %%
df.mean()
# Out:
# C:\Users\rushi\AppData\Local\Temp\ipykernel_2128\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# Age                    32.101365
# ApplicantIncome      5403.459283
# CoapplicantIncome    1621.245798
# LoanAmount            146.412162
# Loan_Amount_Term      342.000000
# Credit_History          0.842199
# dtype: float64

# %%
df['Age'].mean()
# Out:
# 32.10136452241716

# %%
df.median()
# Out:
# C:\Users\rushi\AppData\Local\Temp\ipykernel_2128\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# Age                    30.0
# ApplicantIncome      3812.5
# CoapplicantIncome    1188.5
# LoanAmount            128.0
# Loan_Amount_Term      360.0
# Credit_History          1.0
# dtype: float64

# %%
df.iloc[:,2].median()
# Out:
# 30.0

# %%
df.min()
# Out:
# C:\Users\rushi\AppData\Local\Temp\ipykernel_2128\3962516015.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.min()
# Loan_ID              LP001002
# Age                      24.0
# Education            Graduate
# ApplicantIncome           150
# CoapplicantIncome         0.0
# LoanAmount                9.0
# Loan_Amount_Term         12.0
# Credit_History            0.0
# Property_Area           Rural
# Loan_Status                 N
# dtype: object

# %%
df['Age'].min()
# Out:
# 24.0

# %%
df.std()
# Out:
# C:\Users\rushi\AppData\Local\Temp\ipykernel_2128\3390915376.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# Age                     7.732178
# ApplicantIncome      6109.041673
# CoapplicantIncome    2926.248369
# LoanAmount             85.587325
# Loan_Amount_Term       65.120410
# Credit_History          0.364878
# dtype: float64

# %%
df['Age'].std()
# Out:
# 7.732178229043358

# %%
df.groupby('Age').count()
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# Age
# 24.0       22      21       21          19         22             20
# 25.0      107     105      107         105        107            102
# 26.0       87      86       87          87         87             81
# 27.0       23      23       22          22         23             22
# 28.0        4       4        4           4          4              2
# 30.0       53      53       53          52         53             52
# 31.0       23      22       23          20         23             23
# 32.0       18      18       18          18         18             18
# 35.0        7       7        7           6          7              7
# 37.0       18      17       18          18         18             16
# 38.0       23      23       23          23         23             23
# 40.0       22      20       22          22         22             20
# ...

# %% [markdown]
# ## 3.2 Iris DataSet

# %%
df=pd.read_csv("https://raw.githubusercontent.com/rushirao17/SPPU-Practs/main/iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.groupby("Species").count()
# Out:
#                  Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa      50             50            50             50            50
# Iris-versicolor  50             50            50             50            50
# Iris-virginica   50             50            50             50            50

# %%
df.groupby("Species").mean()
# Out:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5          5.006         3.418          1.464
# Iris-versicolor   75.5          5.936         2.770          4.260
# Iris-virginica   125.5          6.588         2.974          5.552
#
#                  PetalWidthCm
# Species
# Iris-setosa             0.244
# Iris-versicolor         1.326
# Iris-virginica          2.026

# %%
import seaborn as sns
sns.violinplot(x="SepalLengthCm",y="Species",data=df)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='Species'>

# %%
df.corr(method='pearson')
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000
